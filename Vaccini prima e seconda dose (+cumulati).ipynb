# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/somministrazioni-vaccini-summary-latest.csv")

# %%
df.head(30)
# Out:
#    data_somministrazione area  totale  sesso_maschile  sesso_femminile  \
# 0             2020-12-27  PAT     102              39               63
# 1             2020-12-27  PIE     912             368              544
# 2             2020-12-27  CAM     720             422              298
# 3             2020-12-27  PAB     143              65               78
# 4             2020-12-27  SAR      65              34               31
# 5             2020-12-27  ITA    6983            3306             3677
# 6             2020-12-27  BAS     106              41               65
# 7             2020-12-27  MOL      50              20               30
# 8             2020-12-27  MAR     200              97              103
# 9             2020-12-27  SIC      71              45               26
# 10            2020-12-27  FVG     262             149              113
# 11            2020-12-27  PUG     506             249              257
# 12            2020-12-27  UMB      85              45               40
# 13            2020-12-27  ABR      37              19               18
# 14            2020-12-27  VDA      20               9               11
# 15            2020-12-27  LOM     697             403              294
# 16            2020-12-27  EMR     964             372              592
# 17            2020-12-27  CAL     274             147              127
# 18            2020-12-27  TOS     619             267              352
# 19            2020-12-27  LIG     131              54               77
# 20            2020-12-27  LAZ     139              66               73
# 21            2020-12-27  VEN     880             395              485
# 22            2020-12-28  ITA     950             435              515
# 23            2020-12-28  CAL       5               2                3
# 24            2020-12-28  SIC     186             110               76
# 25            2020-12-28  SAR      65              25               40
# 26            2020-12-28  LAZ     516             228              288
# 27            2020-12-28  LOM     103              44               59
# 28            2020-12-28  LIG      75              26               49
# 29            2020-12-29  ITA     902             387              515
#
#     categoria_operatori_sanitari_sociosanitari  \
# 0                                           77
# 1                                          760
# 2                                          703
# 3                                           56
# 4                                           65
# 5                                         5811
# 6                                          104
# 7                                           29
# 8                                          184
# 9                                           55
# 10                                         259
# 11                                         398
# 12                                          67
# 13                                          34
# 14                                          20
# 15                                         513
# 16                                         656
# 17                                         272
# 18                                         460
# 19                                          85
# 20                                         139
# 21                                         875
# 22                                         940
# 23                                           5
# 24                                         184
# 25                                          65
# 26                                         515
# 27                                          99
# 28                                          72
# 29                                         869
#
#     categoria_personale_non_sanitario  categoria_ospiti_rsa  categoria_over80  \
# 0                                   5                    20                 0
# 1                                  76                    76                 0
# 2                                  17                     0                 0
# 3                                  87                     0                 0
# 4                                   0                     0                 0
# 5                                 863                   308                 1
# 6                                   2                     0                 0
# 7                                   4                    17                 0
# 8                                  12                     4                 0
# 9                                   1                    15                 0
# 10                                  3                     0                 0
# 11                                 45                    63                 0
# 12                                  2                    16                 0
# 13                                  1                     2                 0
# 14                                  0                     0                 0
# 15                                171                    12                 1
# 16                                282                    26                 0
# 17                                  2                     0                 0
# 18                                146                    13                 0
# 19                                  2                    44                 0
# 20                                  0                     0                 0
# 21                                  5                     0                 0
# 22                                 10                     0                 0
# 23                                  0                     0                 0
# 24                                  2                     0                 0
# 25                                  0                     0                 0
# 26                                  1                     0                 0
# 27                                  4                     0                 0
# 28                                  3                     0                 0
# 29                                 12                    21                 0
#
#     prima_dose  seconda_dose
# 0          102             0
# 1          912             0
# 2          720             0
# 3          143             0
# 4           65             0
# 5         6983             0
# 6          106             0
# 7           50             0
# 8          200             0
# 9           71             0
# 10         262             0
# 11         506             0
# 12          85             0
# 13          37             0
# 14          20             0
# 15         697             0
# 16         964             0
# 17         274             0
# 18         619             0
# 19         131             0
# 20         139             0
# 21         880             0
# 22         950             0
# 23           5             0
# 24         186             0
# 25          65             0
# 26         516             0
# 27         103             0
# 28          75             0
# 29         902             0

# %%
df = df.loc[df['area']=='PUG']

# %%
df
# Out:
#     data_somministrazione area  totale  sesso_maschile  sesso_femminile  \
# 11             2020-12-27  PUG     506             249              257
# 46             2020-12-30  PUG       2               0                2
# 49             2020-12-31  PUG    1629             780              849
# 68             2021-01-01  PUG     144              60               84
# 79             2021-01-02  PUG    2924            1283             1641
# 106            2021-01-03  PUG    1997             938             1059
# 127            2021-01-04  PUG    4481            2003             2478
# 149            2021-01-05  PUG    5068            2229             2839
# 168            2021-01-06  PUG    3898            1643             2255
# 206            2021-01-07  PUG    5678            2434             3244
# 216            2021-01-08  PUG    5313            2234             3079
# 229            2021-01-09  PUG    4792            2212             2580
# 265            2021-01-10  PUG    2331            1051             1280
# 285            2021-01-11  PUG    3727            1578             2149
# 311            2021-01-12  PUG    4134            1734             2400
# 325            2021-01-13  PUG    4477            1698             2779
# 343            2021-01-14  PUG    3932            1545             2387
# 364            2021-01-15  PUG    4395            1797             2598
# 389            2021-01-16  PUG    2315             962             1353
# 412            2021-01-17  PUG    1285             581              704
# 427            2021-01-18  PUG    1823             752             1071
# 468            2021-01-19  PUG    1212             446              766
# 487            2021-01-20  PUG    1425             492              933
# 504            2021-01-21  PUG    1996             836             1160
# 515            2021-01-22  PUG    1396             568              828
# 550            2021-01-23  PUG    2796            1175             1621
# 565            2021-01-24  PUG     871             405              466
#
#      categoria_operatori_sanitari_sociosanitari  \
# 11                                          398
# 46                                            1
# 49                                         1416
# 68                                          137
# 79                                         2651
# 106                                        1668
# 127                                        4213
# 149                                        4415
# 168                                        2945
# 206                                        4938
# 216                                        4293
# 229                                        4106
# 265                                        1802
# 285                                        3013
# 311                                        3330
# 325                                        3500
# 343                                        2896
# 364                                        3417
# 389                                        1529
# 412                                         807
# 427                                        1115
# 468                                         516
# 487                                         697
# 504                                        1300
# 515                                         860
# 550                                        2395
# 565                                         738
#
#      categoria_personale_non_sanitario  categoria_ospiti_rsa  \
# 11                                  45                    63
# 46                                   1                     0
# 49                                 169                    44
# 68                                   7                     0
# 79                                 252                    21
# 106                                186                   143
# 127                                257                    11
# 149                                554                    94
# 168                                577                   376
# 206                                520                   220
# 216                                730                   290
# 229                                443                   239
# 265                                418                   111
# 285                                543                   171
# 311                                599                   204
# 325                                749                   228
# 343                                542                   494
# 364                                483                   495
# 389                                350                   436
# 412                                154                   324
# 427                                264                   444
# 468                                128                   568
# 487                                170                   558
# 504                                174                   522
# 515                                162                   374
# 550                                130                   271
# 565                                118                    15
#
#      categoria_over80  prima_dose  seconda_dose
# 11                  0         506             0
# 46                  0           2             0
# 49                  0        1629             0
# 68                  0         144             0
# 79                  0        2924             0
# 106                 0        1997             0
# 127                 0        4481             0
# 149                 5        5068             0
# 168                 0        3898             0
# 206                 0        5678             0
# 216                 0        5313             0
# 229                 4        4792             0
# 265                 0        2331             0
# 285                 0        3727             0
# 311                 1        4134             0
# 325                 0        4477             0
# 343                 0        3932             0
# 364                 0        4395             0
# 389                 0        2315             0
# 412                 0        1216            69
# 427                 0        1474           349
# 468                 0        1208             4
# 487                 0        1416             9
# 504                 0        1256           740
# 515                 0         992           404
# 550                 0         712          2084
# 565                 0          17           854

# %%
df = df[["data_somministrazione", "prima_dose", "seconda_dose"]]

# %%
df
# Out:
#     data_somministrazione  prima_dose  seconda_dose
# 11             2020-12-27         506             0
# 46             2020-12-30           2             0
# 49             2020-12-31        1629             0
# 68             2021-01-01         144             0
# 79             2021-01-02        2924             0
# 106            2021-01-03        1997             0
# 127            2021-01-04        4481             0
# 149            2021-01-05        5068             0
# 168            2021-01-06        3898             0
# 206            2021-01-07        5678             0
# 216            2021-01-08        5313             0
# 229            2021-01-09        4792             0
# 265            2021-01-10        2331             0
# 285            2021-01-11        3727             0
# 311            2021-01-12        4134             0
# 325            2021-01-13        4477             0
# 343            2021-01-14        3932             0
# 364            2021-01-15        4395             0
# 389            2021-01-16        2315             0
# 412            2021-01-17        1216            69
# 427            2021-01-18        1474           349
# 468            2021-01-19        1208             4
# 487            2021-01-20        1416             9
# 504            2021-01-21        1256           740
# 515            2021-01-22         992           404
# 550            2021-01-23         712          2084
# 565            2021-01-24          17           854

# %%
for i in range(0,df.shape[0]-6):
    df.loc[df.index[i+6],'SMA_7'] = np.round(((df.iloc[i,1]+ df.iloc[i+1,1] +df.iloc[i+2,1]+df.iloc[i+3,1]+ df.iloc[i+4,1]+ df.iloc[i+5,1]+ df.iloc[i+6,1])/7),1)
# Out:
# C:\Users\giuse\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\giuse\Anaconda3\lib\site-packages\pandas\core\indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df['pandas_SMA_7'] = df.iloc[:,1].rolling(window=7).mean()
# Out:
# C:\Users\giuse\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(25)
# Out:
#     data_somministrazione  prima_dose  seconda_dose   SMA_7  pandas_SMA_7
# 11             2020-12-27         506             0     NaN           NaN
# 46             2020-12-30           2             0     NaN           NaN
# 49             2020-12-31        1629             0     NaN           NaN
# 68             2021-01-01         144             0     NaN           NaN
# 79             2021-01-02        2924             0     NaN           NaN
# 106            2021-01-03        1997             0     NaN           NaN
# 127            2021-01-04        4481             0  1669.0   1669.000000
# 149            2021-01-05        5068             0  2320.7   2320.714286
# 168            2021-01-06        3898             0  2877.3   2877.285714
# 206            2021-01-07        5678             0  3455.7   3455.714286
# 216            2021-01-08        5313             0  4194.1   4194.142857
# 229            2021-01-09        4792             0  4461.0   4461.000000
# 265            2021-01-10        2331             0  4508.7   4508.714286
# 285            2021-01-11        3727             0  4401.0   4401.000000
# 311            2021-01-12        4134             0  4267.6   4267.571429
# 325            2021-01-13        4477             0  4350.3   4350.285714
# 343            2021-01-14        3932             0  4100.9   4100.857143
# 364            2021-01-15        4395             0  3969.7   3969.714286
# 389            2021-01-16        2315             0  3615.9   3615.857143
# 412            2021-01-17        1216            69  3456.6   3456.571429
# 427            2021-01-18        1474           349  3134.7   3134.714286
# 468            2021-01-19        1208             4  2716.7   2716.714286
# 487            2021-01-20        1416             9  2279.4   2279.428571
# 504            2021-01-21        1256           740  1897.1   1897.142857
# 515            2021-01-22         992           404  1411.0   1411.000000

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(df['data_somministrazione'], df['seconda_dose'], label='seconda dose', linewidth=5, color='green')
plt.plot(df['data_somministrazione'], df['SMA_7'], label='Media Mobile 7 giorni prima dose', linewidth=5, color='blue')
plt.xlabel('Data')
plt.xticks(rotation=30)
plt.ylabel('Dosi somministrate')
plt.title("Dosi vaccino covid somministrate in Puglia", fontsize=20)
plt.legend(loc=2)
# Out:
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\giuse\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(df['data_somministrazione'], df['seconda_dose'], label='seconda dose', linewidth=5, color='green')
plt.xlabel('Data')
plt.xticks(rotation=30)
plt.ylabel('Dosi somministrate')
plt.title("Dosi vaccino covid somministrate in Puglia", fontsize=20)
plt.legend(loc=2)

# %%
np.cumsum(df['prima_dose'])
np.cumsum(df['seconda_dose'])
# Out:
# 11        0
# 46        0
# 49        0
# 68        0
# 79        0
# 106       0
# 127       0
# 149       0
# 168       0
# 206       0
# 216       0
# 229       0
# 265       0
# 285       0
# 311       0
# 325       0
# 343       0
# 364       0
# 389       0
# 412      69
# 427     418
# 468     422
# 487     431
# 504    1171
# 515    1575
# 550    3659
# 565    4513
# Name: seconda_dose, dtype: int64

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(df['data_somministrazione'] ,np.cumsum(df['prima_dose']), label='prima dose', linewidth=5, color='blue')
plt.plot(df['data_somministrazione'] ,np.cumsum(df['seconda_dose']), label='seconda dose', linewidth=5, color='red')
plt.axvspan(21, 21.2, color='green', alpha=0.5, label='Inizio somm. dose 2')
plt.xlabel('Data')
plt.xticks(rotation=30)
plt.ylabel('Dosi somministrate')
plt.title("Dosi vaccino covid somministrate in Puglia (cumulate)", fontsize=20)
plt.legend(loc=2)
