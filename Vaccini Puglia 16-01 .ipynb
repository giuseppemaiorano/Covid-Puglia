# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/somministrazioni-vaccini-summary-latest.csv")

# %%
df.head(20)
# Out:
#    data_somministrazione area  totale  sesso_maschile  sesso_femminile  \
# 0             2020-12-27  ABR     135              71               64
# 1             2020-12-27  BAS     208              83              125
# 2             2020-12-27  CAL     274             147              127
# 3             2020-12-27  CAM     719             422              297
# 4             2020-12-27  EMR     963             368              595
# 5             2020-12-27  FVG     263             150              113
# 6             2020-12-27  ITA    7418            3550             3868
# 7             2020-12-27  LAZ     179              91               88
# 8             2020-12-27  LIG     135              59               76
# 9             2020-12-27  LOM     766             457              309
# 10            2020-12-27  MAR     200              97              103
# 11            2020-12-27  MOL      50              20               30
# 12            2020-12-27  PAB     144              65               79
# 13            2020-12-27  PAT     100              39               61
# 14            2020-12-27  PIE     908             366              542
# 15            2020-12-27  PUG     555             279              276
# 16            2020-12-27  SAR      65              34               31
# 17            2020-12-27  SIC      90              55               35
# 18            2020-12-27  TOS     620             267              353
# 19            2020-12-27  UMB     144              76               68
#
#     categoria_operatori_sanitari_sociosanitari  \
# 0                                          115
# 1                                          208
# 2                                          272
# 3                                          711
# 4                                          657
# 5                                          260
# 6                                         5959
# 7                                          178
# 8                                          102
# 9                                          731
# 10                                         188
# 11                                          32
# 12                                         144
# 13                                          77
# 14                                          74
# 15                                         482
# 16                                          65
# 17                                          63
# 18                                         579
# 19                                         122
#
#     categoria_personale_non_sanitario  categoria_ospiti_rsa
# 0                                  18                     2
# 1                                   0                     0
# 2                                   2                     0
# 3                                   8                     0
# 4                                 280                    26
# 5                                   3                     0
# 6                                1138                   321
# 7                                   1                     0
# 8                                   3                    30
# 9                                  23                    12
# 10                                  8                     4
# 11                                  1                    17
# 12                                  0                     0
# 13                                  3                    20
# 14                                758                    76
# 15                                 11                    62
# 16                                  0                     0
# 17                                  2                    25
# 18                                 11                    30
# 19                                  5                    17

# %%
df = df.loc[df["area"]=="PUG"]

# %%
df.head()
# Out:
#     data_somministrazione area  totale  sesso_maschile  sesso_femminile  \
# 15             2020-12-27  PUG     555             279              276
# 58             2020-12-31  PUG    1274             618              656
# 72             2021-01-01  PUG     179              77              102
# 92             2021-01-02  PUG    2903            1278             1625
# 112            2021-01-03  PUG    1921             907             1014
#
#      categoria_operatori_sanitari_sociosanitari  \
# 15                                          482
# 58                                         1202
# 72                                          179
# 92                                         2789
# 112                                        1797
#
#      categoria_personale_non_sanitario  categoria_ospiti_rsa
# 15                                  11                    62
# 58                                  56                    16
# 72                                   0                     0
# 92                                 106                     8
# 112                                 57                    67

# %%
df = df[['area', 'totale']]

# %%
df.head()
# Out:
#     area  totale
# 15   PUG     555
# 58   PUG    1274
# 72   PUG     179
# 92   PUG    2903
# 112  PUG    1921

# %%
for i in range(0,df.shape[0]-2):
    df.loc[df.index[i+2],'SMA_3'] = np.round(((df.iloc[i,1]+ df.iloc[i+1,1] +df.iloc[i+2,1])/3),1)

# %%
df['pandas_SMA_3'] = df.iloc[:,1].rolling(window=3).mean()

# %%
df.head()
# Out:
#     area  totale   SMA_3  pandas_SMA_3
# 15   PUG     555     NaN           NaN
# 58   PUG    1274     NaN           NaN
# 72   PUG     179   669.3    669.333333
# 92   PUG    2903  1452.0   1452.000000
# 112  PUG    1921  1667.7   1667.666667

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(df['totale'],label='Dosi Somministrate', linewidth=2, linestyle='--')
plt.plot(df['SMA_3'],label='Media Mobile 3 giorni', linewidth=8)
plt.xlabel('Giorni')
plt.ylabel('Dosi Somministrate')
plt.title("Andamento Dosi Somministrate Vaccino Puglia", fontsize=20)
plt.legend(loc=2)

# %%
for i in range(0,df.shape[0]-6):
    df.loc[df.index[i+6],'SMA_7'] = np.round(((df.iloc[i,1]+ df.iloc[i+1,1] +df.iloc[i+2,1]+df.iloc[i+3,1]+ df.iloc[i+4,1]+ df.iloc[i+5,1]+ df.iloc[i+6,1])/7),1)

# %%
df['pandas_SMA_7'] = df.iloc[:,1].rolling(window=7).mean()

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(df['totale'],label='Dosi Somministrate', linewidth=2, linestyle='--')
plt.plot(df['SMA_7'],label='Media Mobile 7 giorni', linewidth=8)
plt.xlabel('Tempo')
plt.ylabel('Dosi Somministrate')
plt.title("Andamento Dosi Somministrate Vaccino Puglia", fontsize=20)
plt.legend(loc=2)
